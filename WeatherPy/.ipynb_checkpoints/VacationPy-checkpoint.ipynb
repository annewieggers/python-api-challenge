# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
# output data
cities_csv = pd.read_csv('output_data/cities.csv')

# Show data csv file cities and rows with empty cells
cities_csv.dropna()

# put into a dataframe
cities = pd.DataFrame(cities_csv)
cities
len(cities)
# Out:
# 548

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Configure gmaps with API key
gmaps.configure(api_key=g_key)

# %%
# Store 'Lat' and 'Lng' into  locations 
locations = cities[["Lat", "Lng"]].astype(float)

# Store humidity data for heatmap layer
humidity = cities["Humidity"].astype(float)

# %%
# Create a Heatmap layer
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 2)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
# Filter for temperature > 70 and < 80
cities = cities.loc[cities["Max Temp"] > 70, :]
cities = cities.loc[cities["Max Temp"] < 80, :]
    
# Filter for windspeed < 10
cities = cities.loc[cities["Wind Speed"] < 10 , :]
    
# Filter for zero cloudiness
cities = cities.loc[cities["Cloudiness"] == 0, :]    
 
len(cities)
# Out:
# 8

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# Hotel list
hotels = []

# update df with Hotel Name
cities["Hotel Name"]= ""
hotel_df = cities
hotel_df.reset_index(drop=True, inplace=True)
hotel_df.drop('City_ID', axis=1)
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat    Lng  \
# 0         opuwo           0     NaN  1558378523        23 -18.06  13.84
# 1  ponta do sol           0      BR  1558378767        57 -20.63 -46.00
# 2      cidreira           0      BR  1558378770        66 -30.17 -50.22
# 3     morondava           0      MG  1558378780        69 -20.30  44.28
# 4         vaini           0      IN  1558378780        88  15.34  74.49
# 5         nador           0      MA  1558378499        40  35.17  -2.93
# 6         mogok           0      MM  1558378844        51  22.92  96.51
# 7       birjand           0      IR  1558378880        26  32.86  59.22
#
#    Max Temp  Wind Speed Hotel Name
# 0     72.06        5.44
# 1     73.68        5.32
# 2     76.56        5.50
# 3     79.08        9.06
# 4     78.90        1.59
# 5     75.20        6.93
# 6     72.24        2.77
# 7     71.60        9.17

# %%
# params dictionary to update each iteration

# Base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# geocoordinates
target_search = "lodging"
target_radius = 5000
target_type = "hotel"

# set up a parameters dictionary
params = {
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": g_key
}

for index, row in hotel_df.iterrows():
    # get lat, lng from df
    lat = row["Lat"]
    lng = row["Lng"]

    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"

    # Use the search term: "International Airport" and our lat/lng
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # make request and print url
    response = requests.get(base_url, params=params).json()
    print(json.dumps(response, indent=4, sort_keys=True))

    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        hotels.append(response["results"][0]["name"])
    except (KeyError, IndexError):
        print("No hotel found.")
# Out:
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -18.0591931,
#                     "lng": 13.8405505
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -18.05777972010728,
#                         "lng": 13.84192097989272
#                     },
#                     "southwest": {
#                         "lat": -18.06047937989272,
#                         "lng": 13.83922132010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Ohakane Guesthouse",
#             "photos": [
#                 {
#                     "height": 2250,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101835778943666807491\">Alberto Bozzato</a>"
#                     ],
#                     "photo_reference": "ATtYBwJ-a-mvd_H9sAHAE9cRmfEwa1AQuy8en1FXHPYWxRwUYzDJAUL_oahW9Ujio1TtqYdtWWyXqC6pSPzBFWvqE9-Sp6iR-D1ZDS4-_nKgpWr0iQ6fVMFt4p2FTUwLKxNcFbMUOa1wFf0nPdHJPOHmPtfy6GDt7hrQV6uLjXWjM_JCYOg6",
#                     "width": 4000
#                 }
#             ],
#             "place_id": "ChIJm2q4asmTkBsRODcAS7HS16E",
#             "plus_code": {
#                 "compound_code": "WRRR+86 Opuwo, Namibia",
#                 "global_code": "5FHMWRRR+86"
#             },
#             "rating": 3.7,
#             "reference": "ChIJm2q4asmTkBsRODcAS7HS16E",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 106,
#             "vicinity": "Opuwo"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -18.0446824,
#                     "lng": 13.8335005
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -18.04348247010728,
#                         "lng": 13.83472832989272
#                     },
#                     "southwest": {
#                         "lat": -18.04618212989272,
#                         "lng": 13.83202867010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "
",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 4,
#             "vicinity": "Rua Jangadeiros, !80 Escarpas do Lago Jose Mendes Junior, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6335448,
#                     "lng": -46.0303404
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.63216997010727,
#                         "lng": -46.02897407010728
#                     },
#                     "southwest": {
#                         "lat": -20.63486962989272,
#                         "lng": -46.03167372989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Kanto Island Inn Suites & Spa",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2848,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103273964572684594071\">Pousada Kanto da Ilha Suites &amp; Spa</a>"
#                     ],
#                     "photo_reference": "ATtYBwIu0VeffbXVWrr99DD6iQ3f2DE4TzdSwPfbWkbIY3F7hih2GzrxpybJBelP5g73hxqzrYNpdKvfjoTrWrtA4uTLkV4_sLNQ6DyuERRGW__X6YaH5pLRFrbFGomYBHJ0ahq30rrmJnt0APPm4kxzTEE6zw11HbvGBXipTVo8yixlbsxd",
#                     "width": 4288
#                 }
#             ],
#             "place_id": "ChIJm_NL--w8tJQR8vHCUJO_GGs",
#             "plus_code": {
#                 "compound_code": "9X89+HV Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9X89+HV"
#             },
#             "rating": 4.7,
#             "reference": "ChIJm_NL--w8tJQR8vHCUJO_GGs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 309,
#             "vicinity": "R. Vicente Paulo Ramos - \u00c1guas das Vertentes, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6479,
#                     "lng": -46.00873199999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.64657327010728,
#                         "lng": -46.00754727010727
#                     },
#                     "southwest": {
#                         "lat": -20.64927292989272,
#                         "lng": -46.01024692989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hostel Escarpas do Lago",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1534,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100484267240597892695\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwKlWd3QHSaRZYlz_zzEkp8IjYBh5J6oG0bwA-yHoyPUMmrrmFeJKpnZjNwucnuN-iMJuqomUWU0LyERPj5gFYmJ5EIEvBaCjF8rsWdvAtRndXhuHze3WnedD7qtietNg-15dJcQppGgNBB16vBWlBIucd_IO3XtJZySscUhYV_K00OB",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJ6yyJly89tJQRQEmddxiGHQA",
#             "plus_code": {
#                 "compound_code": "9X2R+RG Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9X2R+RG"
#             },
#             "rating": 4.5,
#             "reference": "ChIJ6yyJly89tJQRQEmddxiGHQA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 85,
#             "vicinity": "Av. das Caravelas, 325 - Escarpas do Lago, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6456114,
#                     "lng": -46.0097467
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.64426157010728,
#                         "lng": -46.00839687010728
#                     },
#                     "southwest": {
#                         "lat": -20.64696122989272,
#                         "lng": -46.01109652989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Escarpas do Lago",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 960,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102771479077732161127\">Escarpas Turismo</a>"
#                     ],
#                     "photo_reference": "ATtYBwLlc-s60Pl1RllyzwzGNu_IJq3GdT3XOfCmhD4JgUWSxfKc-ZTRZByVINK4tW0q8ujWGwGz_zBaBWQFTF4SUaTEqA5KllpsBAfpowPy-8tpZPKGZNPLxmPGYtI7UhSumo7rg-vtCEn1maUqwA_T05DaiwOhQtdTHbMqpFmGlrpC1qDM",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJx8uifYE7tJQRf98euuRPbR4",
#             "plus_code": {
#                 "compound_code": "9X3R+Q4 Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9X3R+Q4"
#             },
#             "rating": 4.2,
#             "reference": "ChIJx8uifYE7tJQRf98euuRPbR4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 918,
#             "vicinity": "Avenida das Caravelas, Engenheiro Jos\u00e9 Mendes J\u00fanior, 25 - Escarpas do Lago, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6213492,
#                     "lng": -46.0404692
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.61998367010728,
#                         "lng": -46.03915092010728
#                     },
#                     "southwest": {
#                         "lat": -20.62268332989272,
#                         "lng": -46.04185057989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Encantos de Capitolio",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2269,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108946325875433562004\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBw
",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 147,
#             "vicinity": "Rua Joaquim Ramos de Oliveira, 445 - \u00c1gua das Vertentes, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6324093,
#                     "lng": -46.0304527
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.63103112010728,
#                         "lng": -46.02908822010727
#                     },
#                     "southwest": {
#                         "lat": -20.63373077989272,
#                         "lng": -46.03178787989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Pousada Viver Capit\u00f3lio",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113919254406709850131\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwIZMG1V3nl0b2ulvTHWl8TU35yb6zt1IrPAFkYm4ATpsxPr87Ss8dnSGK4LbAs91p4ASD6tVUTu2Cfk4UEgdrEHfU4za9Q_iEhfpakByKKsgqioXz1umBNk2c0PuPdk6sLrNeneypOHgW8iN-cdW6f37gQFbh1kA2uOjxkXgY3h1fQh",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJA7HJmTk9tJQRpxuqhiLzlGE",
#             "plus_code": {
#                 "compound_code": "9X99+2R Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9X99+2R"
#             },
#             "rating": 4.8,
#             "reference": "ChIJA7HJmTk9tJQRpxuqhiLzlGE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 41,
#             "vicinity": "R. Clotilde Hort\u00eancio Ramos, 565 - \u00c1guas das Vertentes, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6324761,
#                     "lng": -46.0305855
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.63114467010728,
#                         "lng": -46.02920627010727
#                     },
#                     "southwest": {
#                         "lat": -20.63384432989272,
#                         "lng": -46.03190592989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Chal\u00e9s Capit\u00f3lio",
#             "photos": [
#                 {
#                     "height": 1184,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114262790031408299791\">Carlos Eduardo Vechini Reis</a>"
#                     ],
#                     "photo_reference": "ATtYBwKYjev4wg6j5RfZeNWTqVwfNFq0FHE4PzgyXF2pJZlr8i538HNFuo4LdGEmtHiUZKEXGFeTPPqk1uM3F_U_zqC90Rrn7si01mKotM8wW-640TC6lC1KChcma0HUZr6gSfGYfdzM5pXa49shbrEWD1Pv7Ci_Vo6DCnS7rpQcyl2EZdMv",
#                     "width": 2560
#                 }
#             ],
#             "place_id": "ChIJD9jPUOw8tJQRkuXjDzcx3Vo",
#             "plus_code": {
#                 "compound_code": "9X99+2Q Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9X99+2Q"
#             },
#             "rating": 5,
#             "reference": "ChIJD9jPUOw8tJQRkuXjDzcx3Vo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 50,
#             "vicinity": "R. das \u00c2ncoras, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6336191,
#                     "lng": -46.030546
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.63231247010728,
#                         "lng": -46.02916822010727
#                     },
#                     "southwest": {
#                         "lat": -20.63501212989272,
#                         "lng": -46.03186787989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Pousada Vale do Chap\u00e9u",
#             "photos": [
#                 {
#                     "height": 725,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111103269765682818499\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwKWPo18HlbPfa9n8oTgKDkeHTkKkaY3bnGEaVn45MAoAHQX1hjv6kL8cEEPAV2g5vNNp_V6pqR0cVWVhv_bBHoDrDJJh3erPT5Mw_avcPzNsNPCLeGGCF3GpCTEUrdZ-KpJhL2sE2icscEpjftEj1StiV4qC5nW_7lfJcTFSd9CgpCo",
#                     "width": 960
#                 }
#             ],
#             "place_id": "ChIJnU8z5Ow8tJQRQJxdVi2TsHQ",
#             "plus_code": {
#                 "compound_code": "9X89+HQ Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9X89+HQ"
#             },
#             "rating": 4.8,
#             "reference": "ChIJnU8z5Ow8tJQRQJxdVi2TsHQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 152,
#             "vicinity": "Estrada Capit\u00f3lio KM 2,5 - Condom\u00ednio do Gat\u00e3o - Escarpas do Lago, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.63318,
#                     "lng": -46.026913
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.63161537010727,
#                         "lng": -46.02573077010728
#                     },
#                     "southwest": {
#                         "lat": -20.63431502989271,
#                         "lng": -46.02843042989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Chal\u00e9s Cantinho da Ro\u00e7a",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 672,
#                     "html_attributions": [
# ...
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101327691235121959712\">ali es</a>"
#                     ],
#                     "photo_reference": "ATtYBwL2DiSWSJF-oOcf5RtC4weklR_wqhM98CPU-EIOVymrXrNJ_e650LxG3h61l-0442_dPcZkCg7S7jV2guPm_79FQ_U8Qo19r2DprfNiKGLHOzmi9o2H23shBnAmb7_iGC_eWqovIjLq9bnbK2iSN-TXB8D_Jf0OY-0k60W-DbHWqqvr",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJVXs2_JBdGj8RcXZjNohxJWI",
#             "plus_code": {
#                 "compound_code": "V67H+W4 Birjand, South Khorasan Province, Iran",
#                 "global_code": "8H4XV67H+W4"
#             },
#             "rating": 4,
#             "reference": "ChIJVXs2_JBdGj8RcXZjNohxJWI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 26,
#             "vicinity": "Birjand"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 32.8654403,
#                     "lng": 59.21857749999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.86678902989272,
#                         "lng": 59.21988987989272
#                     },
#                     "southwest": {
#                         "lat": 32.86408937010728,
#                         "lng": 59.21719022010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "\u0622\u0645\u0648\u0632\u0634\u06af\u0627\u0647 \u06a9\u0648\u06cc\u0631\u0627\u0646",
#             "place_id": "ChIJrRz520pdGj8RXQJqgjauDcA",
#             "plus_code": {
#                 "compound_code": "V689+5C Birjand, South Khorasan Province, Iran",
#                 "global_code": "8H4XV689+5C"
#             },
#             "rating": 0,
#             "reference": "ChIJrRz520pdGj8RXQJqgjauDcA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "Birjand, \u062e\u06cc\u0627\u0628\u0627\u0646 \u0646\u0648\u0627\u0628 \u0635\u0641\u0648\u06cc\u060c"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 32.8861147,
#                     "lng": 59.22042390000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.88734712989272,
#                         "lng": 59.22188512989273
#                     },
#                     "southwest": {
#                         "lat": 32.88464747010728,
#                         "lng": 59.21918547010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Moghaddam Hotel",
#             "photos": [
#                 {
#                     "height": 2976,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107518740725472145372\">Ebrahim foroutan tanha</a>"
#                     ],
#                     "photo_reference": "ATtYBwKME1KwRLwv1HsbdiILc2DoZOWjf3iQjkb8qfDFSITlI4Uo1oDcBZlAK85ACu19YW-aOuZ9nzLL47RTLu-g2N5tAlcob7UYpinkNy2x0oautlaXB2xJMbEGMkx2RHB9p8OG3pOGi5-DFX5W0KMfTYHpwbgK9BqEjBRrzB99ltkRjAw6",
#                     "width": 3968
#                 }
#             ],
#             "place_id": "ChIJA9iUCmhnGj8RsHrgqYggyJE",
#             "plus_code": {
#                 "compound_code": "V6PC+C5 Birjand, South Khorasan Province, Iran",
#                 "global_code": "8H4XV6PC+C5"
#             },
#             "rating": 4,
#             "reference": "ChIJA9iUCmhnGj8RsHrgqYggyJE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 21,
#             "vicinity": "Birjand, \u062c\u0646\u0628 \u067e\u0627\u0631\u06a9 \u0622\u0632\u0627\u062f\u06cc\u060c \u0628\u0644\u0648\u0627\u0631 \u062c\u0645\u0647\u0648\u0631\u06cc"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 32.849255,
#                     "lng": 59.22447189999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.85060527989272,
#                         "lng": 59.22583637989272
#                     },
#                     "southwest": {
#                         "lat": 32.84790562010727,
#                         "lng": 59.22313672010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "\u0646\u0627\u0631\u06af\u0644",
#             "place_id": "ChIJV7D4u9hdGj8RLFySJk7CI8A",
#             "plus_code": {
#                 "compound_code": "R6XF+PQ Birjand, South Khorasan Province, Iran",
#                 "global_code": "8H4XR6XF+PQ"
#             },
#             "rating": 0,
#             "reference": "ChIJV7D4u9hdGj8RLFySJk7CI8A",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "\u0628\u064a\u0631\u062c\u0646\u062f\u060c \u0627\u0633\u062a\u0627\u0646 \u062e\u0631\u0627\u0633\u0627\u0646 \u062c\u0646\u0648\u0628\u06cc\u060c"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 32.8273866,
#                     "lng": 59.1833077
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.82876562989272,
#                         "lng": 59.18460737989273
#                     },
#                     "southwest": {
#                         "lat": 32.82606597010728,
#                         "lng": 59.18190772010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Mountain Hotel",
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112258440659091410340\">Shahin Merat</a>"
#                     ],
#                     "photo_reference": "ATtYBwISwkta-AZCX0jX5E5ZtMOQXc4lGFXlYgwjfhysbnbUq0oBri0IY9YYWJ-kld1dQgy8aaYe6ewVGH9oVJtwMD7b7-VY_oG-dn8yUf32FfRk4IEXMnrV_Up3ARaQkoyyN_CrBdVWNs8v6uCIkImL5uoByHpOH5CJNp-e-MX08NwfPvVL",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJ842B4WJeGj8Rf_DKDkyHnBE",
#             "plus_code": {
#                 "compound_code": "R5GM+X8 Birjand, South Khorasan Province, Iran",
#                 "global_code": "8H4XR5GM+X8"
#             },
#             "rating": 4.2,
#             "reference": "ChIJ842B4WJeGj8Rf_DKDkyHnBE",
#             "scope": "GOOGLE",
#             "types": [
#                 "cafe",
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 134,
#             "vicinity": "Birjand"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 32.8713752,
#                     "lng": 59.2307798
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.87281897989271,
#                         "lng": 59.23214542989272
#                     },
#                     "southwest": {
#                         "lat": 32.87011932010727,
#                         "lng": 59.22944577010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Birjand Tourist Hotel",
#             "photos": [
#                 {
#                     "height": 1190,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113015329849967088586\">majid mirzaei</a>"
#                     ],
#                     "photo_reference": "ATtYBwJAK7VW4QlaohqFcI_SudtSajCt9_VdOdPWwCRc92gzJIL1jWQZt7jb48vb9fvvbl21HUfWCKDdbiGDhrcRM8UtIUl80VUYGYXCdDqIL-FelRvlCa_uSJbhE2ZLCLotxTZGYgVNExiCEfbp7nebnontNBdNreVoPyi_ayKmqXOwz9gw",
#                     "width": 1200
#                 }
#             ],
#             "place_id": "ChIJ3YvQoZFdGj8RlV74-3yR6NY",
#             "plus_code": {
#                 "compound_code": "V6CJ+H8 Birjand, South Khorasan Province, Iran",
#                 "global_code": "8H4XV6CJ+H8"
#             },
#             "rating": 3.9,
#             "reference": "ChIJ3YvQoZFdGj8RlV74-3yR6NY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 89,
#             "vicinity": "Birjand"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 32.8859566,
#                     "lng": 59.220002
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.88738412989272,
#                         "lng": 59.22126852989272
#                     },
#                     "southwest": {
#                         "lat": 32.88468447010727,
#                         "lng": 59.21856887010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Sepehr Hotel",
#             "photos": [
#                 {
#                     "height": 3264,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117721819966759805193\">Javad Rezayi</a>"
#                     ],
#                     "photo_reference": "ATtYBwLiQEABR-A2vjvbex6D9o5xviNqJ1OUFTE4OPB9azQmKNJz0DrAu8OQrB5TuA9OLpxqe7BIyNfPVfEBA3FzQ6yBsdNo4ScLei7A9D4CtiPUZoQvJNCyUIgsnFeNFiEiNIveoaDsn7eH_xvXMgQLV45G8ZkADQn4D8UEL1nZ615BLDA_",
#                     "width": 4928
#                 }
#             ],
#             "place_id": "ChIJtf7cCWhnGj8RnZidlgcKfvY",
#             "plus_code": {
#                 "compound_code": "V6PC+92 Birjand, South Khorasan Province, Iran",
#                 "global_code": "8H4XV6PC+92"
#             },
#             "rating": 4.1,
#             "reference": "ChIJtf7cCWhnGj8RnZidlgcKfvY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 62,
#             "vicinity": "Birjand"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 32.8538677,
#                     "lng": 59.20327139999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.85515842989271,
#                         "lng": 59.20462027989271
#                     },
#                     "southwest": {
#                         "lat": 32.85245877010727,
#                         "lng": 59.20192062010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "\u0627\u0645\u0644\u0627\u06a9 \u062f\u0631\u06cc\u0627\u06cc\u06cc \u0634\u0639\u0628\u0647 2",
#             "place_id": "ChIJqdGAj9ldGj8RBUucF_SmV5Q",
#             "plus_code": {
#                 "compound_code": "V633+G8 Birjand, South Khorasan Province, Iran",
#                 "global_code": "8H4XV633+G8"
#             },
#             "rating": 0,
#             "reference": "ChIJqdGAj9ldGj8RBUucF_SmV5Q",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "\u0627\u0633\u062a\u0627\u0646 \u062e\u0631\u0627\u0633\u0627\u0646 \u062c\u0646\u0648\u0628\u06cc\u060c \u0628\u064a\u0631\u062c\u0646\u062f\u060c \u0628\u0644\u0648\u0627\u0631 \u063a\u062f\u06cc\u0631\u060c"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 32.8649039,
#                     "lng": 59.2262472
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.86625672989273,
#                         "lng": 59.22757177989273
#                     },
#                     "southwest": {
#                         "lat": 32.86355707010728,
#                         "lng": 59.22487212010729
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "\u0628\u06cc\u0645\u0631\u0632",
#             "place_id": "ChIJz3gYA9ldGj8RBuvQ00H_CSg",
#             "plus_code": {
#                 "compound_code": "V67G+XF Birjand, South Khorasan Province, Iran",
#                 "global_code": "8H4XV67G+XF"
#             },
#             "rating": 0,
#             "reference": "ChIJz3gYA9ldGj8RBuvQ00H_CSg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 0,
#             "vicinity": "\u0628\u06cc\u0645\u0631\u0632\u060c\u060c \u0628\u064a\u0631\u062c\u0646\u062f\u060c"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 32.8301461,
#                     "lng": 59.2193318
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.83125897989273,
#                         "lng": 59.22158779999999
#                     },
#                     "southwest": {
#                         "lat": 32.82855932010728,
#                         "lng": 59.21857980000001
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "\u0647\u062a\u0644 5 \u0633\u062a\u0627\u0631\u0647 \u0628\u0646\u062f \u062f\u0631\u0647",
#             "place_id": "ChIJjaaJBkpcGj8RCFTy04HHpH4",
#             "plus_code": {
#                 "compound_code": "R6J9+3P Birjand, South Khorasan Province, Iran",
#                 "global_code": "8H4XR6J9+3P"
#             },
#             "rating": 5,
#             "reference": "ChIJjaaJBkpcGj8RCFTy04HHpH4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Birjand"
#         }
#     ],
#     "status": "OK"
# }

# %%
# Update DF with hotel name
hotel_df["Hotel Name"] = hotels
print(hotel_df["Hotel Name"])
hotel_df.head()
# Out:
# 0                             Ohakane Guesthouse
# 1                            Pousada Buena Vista
# 2                                  Hotel Castelo
# 3            Palissandre Cote Ouest resort & SPA
# 4                       Dandeli Mist Jungle Stay
# 5    Hotel Marchica Lagoon Resort, Nador Morocco
# 6                               MOGOK HILL HOTEL
# 7                                     مجتمع آریا
# Name: Hotel Name, dtype: object
#    City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0        7         opuwo           0     NaN  1558378523        23 -18.06
# 1       70  ponta do sol           0      BR  1558378767        57 -20.63
# 2       88      cidreira           0      BR  1558378770        66 -30.17
# 3      138     morondava           0      MG  1558378780        69 -20.30
# 4      139         vaini           0      IN  1558378780        88  15.34
#
#      Lng  Max Temp  Wind Speed                           Hotel Name
# 0  13.84     72.06        5.44                   Ohakane Guesthouse
# 1 -46.00     73.68        5.32                  Pousada Buena Vista
# 2 -50.22     76.56        5.50                        Hotel Castelo
# 3  44.28     79.08        9.06  Palissandre Cote Ouest resort & SPA
# 4  74.49     78.90        1.59             Dandeli Mist Jungle Stay

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Create a marker_layer using the hotel info list to fill the info box
markers = gmaps.marker_layer(locations, info_box_content= [f"{hotel_info}" for hotel in hotels])
fig.add_layer(markers)

# Display Map
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Save fig
plt.savefig("output_Data/Heatmap with markers VacationPy")
